# %% [markdown]
# # HuggingFace로 기계번역 구현하기
#
# 이번에는 HuggingFace로 기계번역 모델을 학습해 볼 것입니다.
# 먼저 필요한 library들을 설치하고 import합시다.

# %%
# !pip install transformers datasets evaluate accelerate scikit-learn sacrebleu sentencepiece
# Out:
# Requirement already satisfied: transformers in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (4.44.2)
# Requirement already satisfied: datasets in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (2.21.0)
# Requirement already satisfied: evaluate in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: accelerate in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (0.34.2)
# Requirement already satisfied: scikit-learn in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: sacrebleu in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (2.4.3)
# Requirement already satisfied: sentencepiece in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: filelock in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: psutil in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: torch>=1.10.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from accelerate) (2.4.1+cu124)
# Requirement already satisfied: scipy>=1.6.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: portalocker in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from sacrebleu) (2.10.1)
# Requirement already satisfied: tabulate>=0.8.9 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from sacrebleu) (5.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: sympy in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.99 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.99 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.99 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.2.65 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.2.65)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.0.44 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.2.0.44)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.119 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.5.119)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.0.99 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.6.0.99)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.0.142 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.3.0.142)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.99 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.99 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: triton==3.0.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/shhj1998/miniconda3/envs/pytorch-2.4.1/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import random
import evaluate
import numpy as np

from datasets import load_dataset
from transformers import AutoTokenizer

# %% [markdown]
# ## Dataset 준비
#
# 기계번역을 위한 dataset을 준비하겠습니다.
# Dataset은 `Helsinki-NLP/opus-100`을 활용합니다.

# %%
books = load_dataset("Helsinki-NLP/opus-100", "en-ko")
books["train"][1]
# Out:
# {'translation': {'en': "I ain't fishing' 'em out.", 'ko': '그거 꺼내려다가는'}}

# %% [markdown]
# 보시다시피 각 data는 영어 문장을 `en`에, 한국어 문장을 `ko`에 저장하고 있습니다.
#
# 이번에는 tokenizer를 불러와 data를 미리 tokenize 하겠습니다.

# %%
source_lang = "en"
target_lang = "ko"
prefix = "translate English to Korean: "
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-tc-big-en-ko")

def preprocess_function(data):
    inputs = [prefix + text[source_lang] for text in data["translation"]]
    targets = [text[target_lang] for text in data["translation"]]
    model_inputs = tokenizer(inputs, text_target=targets, max_length=128, truncation=True)
    return model_inputs

tokenized_books = books.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %% [markdown]
# 기계번역과 같이 입력과 출력을 모두 tokenize하는 경우에는 출력 text를 `tokenizer`의 `text_target`인자로 넘겨주면 됩니다. 이처럼 기계 번역 dataset을 불러오는 것은 imdb dataset과 별반 다르지 않습니다.
#
# 마지막으로 `data_collator`를 다음과 같이 구현합니다.

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model='google-t5/t5-small')

# %% [markdown]
# ## Model 구현
#
# 이번에는 기계번역을 위한 sequence-to-sequence 모델을 구현하겠습니다.

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

model = AutoModelForSeq2SeqLM.from_pretrained('google-t5/t5-small')
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %% [markdown]
# Sequence-to-sequence 모델은 위와 같이 `AutoModelForSeq2SeqLM`을 활용하면 됩니다.
# Pre-trained 모델로 `google-t5/t5-small`이라는 것을 사용하고 있습니다.
# 이 코드 하나로 우리는 기계 번역과 같은 문제를 풀 수 있는 encoder-decoder 구조의 모델을 구현할 수 있습니다.

# %% [markdown]
# ## 학습
#
# 마지막으로 학습 코드를 구현하겠습니다.
# 학습은 감정 분석과 똑같이 `training_args`를 정의하고 `Trainer`로 이전에 구현한 것들을 모두 수합하면 됩니다.

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="hf_mt",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    weight_decay=0.01,  # 첫 주차 때 배운 weight decay를 조절하는 hyper-parameter입니다.
    save_total_limit=1,
    num_train_epochs=1,
    predict_with_generate=True  # 실제로 평가를 진행할 때는 내부적으로 정의된 beam search 등을 활용하여 text를 생성합니다.
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_books["train"],
    tokenizer=tokenizer,
    data_collator=data_collator
)

# %% [markdown]
# 마지막으로 학습하면 다음과 같습니다.

# %%
trainer.train()
trainer.save_model()
# Out:
#     <div>
#
#       <progress value='62500' max='62500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62500/62500 1:04:56, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>8.898300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>8.187200</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>8.095000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>8.036400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>7.970700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>7.939400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>7.907700</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>7.867400</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>7.866100</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>7.839700</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>7.824700</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>7.814400</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>7.766600</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>7.798400</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>7.761200</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>7.772400</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>7.708300</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>7.728300</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>7.715100</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>7.704300</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>7.723000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>7.678700</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>7.706700</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>7.687500</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>7.685500</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>7.693100</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>7.652300</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>7.685000</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>7.647800</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>7.662400</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>7.658300</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>7.639700</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>7.622500</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>7.638000</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>7.625900</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>7.609000</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>7.605000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>7.578000</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>7.612400</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>7.640000</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>7.619800</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>7.606700</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>7.590000</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>7.588300</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>7.580000</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>7.547300</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>7.560400</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>7.546500</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>7.570000</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>7.538300</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>7.538500</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>7.536200</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>7.537500</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>7.540900</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>7.538400</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>7.526800</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>7.528500</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>7.531400</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>7.504700</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>7.534400</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>7.498900</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>7.486300</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>7.522100</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>7.533300</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>7.485000</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>7.487800</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>7.520600</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>7.512100</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>7.492000</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>7.498200</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>7.470200</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>7.490900</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>7.468500</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>7.473000</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>7.475600</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>7.487300</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>7.470400</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>7.452500</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>7.487700</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>7.475800</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>7.450600</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>7.437700</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>7.457500</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>7.459700</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>7.455800</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>7.469400</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>7.460800</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>7.442300</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>7.445700</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>7.480800</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>7.442100</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>7.442200</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>7.435600</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>7.432300</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>7.454100</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>7.422200</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>7.439500</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>7.449400</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>7.426900</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>7.404500</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>7.435600</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>7.410900</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>7.420700</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>7.406500</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>7.423500</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>7.437700</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>7.434100</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>7.434000</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>7.429800</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>7.440300</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>7.420100</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>7.447100</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>7.436400</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>7.406600</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>7.423300</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>7.428600</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>7.405100</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>7.427200</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>7.396400</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>7.386600</td>
#     </t
# TrainOutput(global_step=62500, training_loss=7.57248191015625, metrics={'train_runtime': 3897.8165, 'train_samples_per_second': 256.554, 'train_steps_per_second': 16.035, 'total_flos': 1.0393154930343936e+16, 'train_loss': 7.57248191015625, 'epoch': 1.0})

# %% [markdown]
# 학습 결과를 보면 다음과 같습니다.

# %%
from transformers import pipeline

text = "translate English to Korean: Hello! My name is Seunghyuk Cho."
translator = pipeline("translation", model='./hf_mt', max_new_tokens=128, device='cuda', tokenizer=tokenizer)
translator(text)
# Out:
# [{'translation_text': '-의 그 그 그 그 그 그 그 그 그 그 그 그...................................................'}]

# %% [markdown]
# 보시다시피 성능이 그렇게 좋지 않습니다. 아마 더 많은 학습 시간을 요구하는 듯 합니다.
#
# 하지만 중요한 것은 data부터 모델, 학습 코드 구현까지 매우 쉽게 했다는 것입니다.
